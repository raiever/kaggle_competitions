# %%
import pymysql.cursors
from sqlalchemy import create_engine

password = 'password'
db_name = 'kaggle_house_price'
engine = create_engine("mysql://root:"+"%s" % password+"@localhost/%s" % db_name, encoding='utf-8')
conn = engine.connect()

# %%
table_name = 'data_desc'
select_sql = "SELECT * FROM %s" % table_name
data_desc = pd.read_sql(sql=select_sql, con=conn, index_col='index')
conn.close()

# %%
data_desc.head(30)
# Out:
#          Data_Type       Column  \
# index
# 0      Categorical   MSSubClass
# 1      Categorical   MSSubClass
# 2      Categorical   MSSubClass
# 3      Categorical   MSSubClass
# 4      Categorical   MSSubClass
# 5      Categorical   MSSubClass
# 6      Categorical   MSSubClass
# 7      Categorical   MSSubClass
# 8      Categorical   MSSubClass
# 9      Categorical   MSSubClass
# 10     Categorical   MSSubClass
# 11     Categorical   MSSubClass
# 12     Categorical   MSSubClass
# 13     Categorical   MSSubClass
# 14     Categorical   MSSubClass
# 15     Categorical   MSSubClass
# 17     Categorical     MSZoning
# 18     Categorical     MSZoning
# 19     Categorical     MSZoning
# 20     Categorical     MSZoning
# 21     Categorical     MSZoning
# 22     Categorical     MSZoning
# 23     Categorical     MSZoning
# 24     Categorical     MSZoning
# 26       Numerical  LotFrontage
# 27       Numerical      LotArea
# 28     Categorical       Street
# 29     Categorical       Street
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, re

pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 400)
pd.set_option('max_colwidth', 100)

# %%
train = pd.read_csv('./train.csv', index_col='Id')

# %%
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
data_desc[data_desc['Column_Detail'].isnull() != True]
# Out:
#          Data_Type         Column  \
# index
# 0      Categorical     MSSubClass
# 17     Categorical       MSZoning
# 26       Numerical    LotFrontage
# 27       Numerical        LotArea
# 28     Categorical         Street
# 31     Categorical          Alley
# 35     Categorical       LotShape
# 40     Categorical    LandContour
# 45     Categorical      Utilities
# 50     Categorical      LotConfig
# 56     Categorical      LandSlope
# 60     Categorical   Neighborhood
# 86     Categorical     Condition1
# 96     Categorical     Condition2
# 106    Categorical       BldgType
# 112    Categorical     HouseStyle
# 121    Categorical    OverallQual
# 132    Categorical    OverallCond
# 143      Numerical      YearBuilt
# 144      Numerical   YearRemodAdd
# 145    Categorical      RoofStyle
# 152    Categorical       RoofMatl
# 161    Categorical    Exterior1st
# 179    Categorical    Exterior2nd
# 197    Categorical     MasVnrType
# 203      Numerical     MasVnrArea
# ...

# %% [markdown]
# ### 1) Attributes analysis
# - House: MSSubClass, MSZoning, BldgType, HouseStyle, OverallQual, OverallCond, RoofStyle, RoofMatl, Exterior1st,
#          Exterior2nd, MasVnrType, MasVnrArea,
# - Property: LotArea, LotShape, LandContour, LotConfig, LandSlope,
# - Environment: LotFrontage, Street, Alley, Neighborhood, Condition1, Condition2,
# - related time: YearBuilt, YearRemodAdd,
# - facilities: Utilities,
# -

# %%
for col in train.columns:
#     print(col)
    d_type = data_desc[data_desc['Column'] == col].Data_Type.values[0]
    if d_type == 'Categorical':
        sns.catplot(x='%s'%col, y='SalePrice', data=train, kind='swarm')
    else:
        pass
    break
